# %%
import pandas as pd
import numpy as np
import sklearn

print(f"pandas:  {pd.__version__}")
print(f"numpy:   {np.__version__}")
print(f"sklearn: {sklearn.__version__}")
print("\nWszystko działa!")
# Out:
# pandas:  3.0.1
# numpy:   2.4.3
# sklearn: 1.8.0
#
# Wszystko działa!
